# %%
import pandas as pd
import numpy as np
from citipy import citipy

# %%
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)

lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities.

cities = []

#Identify the nearest city for each latitude and lognitude combination. 

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
#Print the city count to fonfirm sufficient count.

len(cities)
# Out:
# 783

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
import time

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url= url + "&q=" + city
city_weather = requests.get(city_url)

# %%
#Create an empty list to hold the weather data

city_data = []

#Print the beggining of the logging.

print("Beginning Data Retrieval    ")

print("----------------------------")


#Create counters.

record_count = 1

set_count = 1

#Loop through all the cities in our list.

for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        time.sleep(60)
        
        #Creae endpoint URL with each city.
        
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, and set numbers and the city.
    
    print(F"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count.
    
    record_count += 1
    
#Run an AP request for each of the cities.
    try:
        #Parse the JSON and retrieve the data.
        
        city_weather = requests.get(city_url).json()
        
        #Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
        
        city_description = city_weather["weather"][0]["description"]
        
   
        
        #Append the city information into a city_data list.
        
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng" : city_lng,
                         "Max Temp" : city_max_temp,
                         "Humidity" : city_humidity,
                         "Cloudiness" : city_clouds,
                         "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description" : city_description})
        
#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping ...")
        pass
    
#Indicate that Data Loading is complete.

print("------------------------------")

print("Data Retrieval Complete       ")

print("------------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | vardo
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | bagdarin
# Processing Record 10 of Set 1 | kabwe
# Processing Record 11 of Set 1 | izyum
# Processing Record 12 of Set 1 | castelo branco
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | kipushi
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | bairiki
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | cecina
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | sungairaya
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | ojhar
# Processing Record 23 of Set 1 | keti bandar
# Processing Record 24 of Set 1 | saldanha
# Processing Record 25 of Set 1 | kloulklubed
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping ...
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | sinazongwe
# Processing Record 31 of Set 1 | celestun
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | concordia
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | jumla
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | nemuro
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping ...
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping ...
# Processing Record 41 of Set 1 | samalaeulu
# City not found. Skipping ...
# Processing Record 42 of Set 1 | axim
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping ...
# Processing Record 44 of Set 1 | luderitz
# Processing Record 45 of Set 1 | victoria
# Processing Record 46 of Set 1 | lorengau
# Processing Record 47 of Set 1 | victor harbor
# Processing Record 48 of Set 1 | tumannyy
# City not found. Skipping ...
# Processing Record 49 of Set 1 | buala
# Processing Record 50 of Set 1 | toliary
# City not found. Skipping ...
# Processing Record 51 of Set 2 | lagoa
# Processing Record 52 of Set 2 | san quintin
# Processing Record 53 of Set 2 | aklavik
# Processing Record 54 of Set 2 | atar
# Processing Record 55 of Set 2 | roald
# Processing Record 56 of Set 2 | bonavista
# Processing Record 57 of Set 2 | mar del plata
# Processing Record 58 of Set 2 | nome
# Processing Record 59 of Set 2 | whitianga
# Processing Record 60 of Set 2 | ushuaia
# Processing Record 61 of Set 2 | buritizeiro
# Processing Record 62 of Set 2 | hualmay
# Processing Record 63 of Set 2 | baruun-urt
# Processing Record 64 of Set 2 | jamestown
# Processing Record 65 of Set 2 | airai
# Processing Record 66 of Set 2 | kruisfontein
# Processing Record 67 of Set 2 | falealupo
# City not found. Skipping ...
# Processing Record 68 of Set 2 | cabra
# Processing Record 69 of Set 2 | busselton
# Processing Record 70 of Set 2 | tasiilaq
# Processing Record 71 of Set 2 | sabirabad
# Processing Record 72 of Set 2 | neiba
# Processing Record 73 of Set 2 | roshchino
# Processing Record 74 of Set 2 | pringsewu
# Processing Record 75 of Set 2 | aguas vermelhas
# Processing Record 76 of Set 2 | palmer
# Processing Record 77 of Set 2 | manjeshwar
# Processing Record 78 of Set 2 | ahipara
# Processing Record 79 of Set 2 | vilhena
# Processing Record 80 of Set 2 | new norfolk
# Processing Record 81 of Set 2 | fort oglethorpe
# Processing Record 82 of Set 2 | calama
# Processing Record 83 of Set 2 | kokopo
# Processing Record 84 of Set 2 | tezu
# Processing Record 85 of Set 2 | shkotovo
# Processing Record 86 of Set 2 | severo-kurilsk
# Processing Record 87 of Set 2 | kalaleh
# Processing Record 88 of Set 2 | murgab
# Processing Record 89 of Set 2 | naryan-mar
# Processing Record 90 of Set 2 | baherden
# Processing Record 91 of Set 2 | geraldton
# Processing Record 92 of Set 2 | roxana
# Processing Record 93 of Set 2 | punta arenas
# Processing Record 94 of Set 2 | saint-pierre
# Processing Record 95 of Set 2 | saskylakh
# Processing Record 96 of Set 2 | ribeira grande
# Processing Record 97 of Set 2 | kitgum
# Processing Record 98 of Set 2 | mfou
# Processing Record 99 of Set 2 | norman wells
# Processing Record 100 of Set 2 | kazalinsk
# City not found. Skipping ...
# Processing Record 101 of Set 3 | yeppoon
# Processing Record 102 of Set 3 | ancud
# Processing Record 103 of Set 3 | hamilton
# Processing Record 104 of Set 3 | narsaq
# Processing Record 105 of Set 3 | saint-philippe
# Processing Record 106 of Set 3 | ambodifototra
# City not found. Skipping ...
# Processing Record 107 of Set 3 | brits
# Processing Record 108 of Set 3 | freeport
# Processing Record 109 of Set 3 | littleton
# Processing Record 110 of Set 3 | lebu
# Processing Record 111 of Set 3 | banda aceh
# Processing Record 112 of Set 3 | ponta do sol
# Processing Record 113 of Set 3 | zhangye
# Processing Record 114 of Set 3 | guerrero negro
# Processing Record 115 of Set 3 | pevek
# Processing Record 116 of Set 3 | la trinidad
# Processing Record 117 of Set 3 | ukiah
# Processing Record 118 of Set 3 | iqaluit
# Processing Record 119 of Set 3 | beringovskiy
# Processing Record 120 of Set 3 | kaitangata
# Processing Record 121 of Set 3 | katsuura
# Processing Record 122 of Set 3 | kuche
# City not found. Skipping ...
# Processing Record 123 of Set 3 | bektemir
# Processing Record 124 of Set 3 | baykit
# Processing Record 125 of Set 3 | ust-nera
# Processing Record 126 of Set 3 | barbar
# City not found. Skipping ...
# Processing Record 127 of Set 3 | kapaa
# Processing Record 128 of Set 3 | sao felix do xingu
# Processing Record 129 of Set 3 | thanh hoa
# Processing Record 130 of Set 3 | deer lake
# Processing Record 131 of Set 3 | pacific grove
# Processing Record 132 of Set 3 | puerto ayora
# Processing Record 133 of Set 3 | isangel
# Processing Record 134 of Set 3 | la ronge
# Processing Record 135 of Set 3 | khatanga
# Processing Record 136 of Set 3 | gondanglegi
# Processing Record 137 of Set 3 | hobyo
# Processing Record 138 of Set 3 | castro
# Processing Record 139 of Set 3 | taoudenni
# Processing Record 140 of Set 3 | nishihara
# Processing Record 141 of Set 3 | seoul
# Processing Record 142 of Set 3 | port elizabeth
# Processing Record 143 of Set 3 | acapulco
# Processing Record 144 of Set 3 | dickinson
# Processing Record 145 of Set 3 | marcona
# City not found. Skipping ...
# Processing Record 146 of Set 3 | belushya guba
# City not found. Skipping ...
# Processing Record 147 of Set 3 | krasnoselkup
# Processing Record 148 of Set 3 | kishapu
# Processing Record 149 of Set 3 | faanui
# Processing Record 150 of Set 3 | sao joao dos patos
# Processing Record 151 of Set 4 | pecos
# Processing Record 152 of Set 4 | alto vera
# City not found. Skipping ...
# Processing Record 153 of Set 4 | fallon
# Processing Record 154 of Set 4 | hithadhoo
# Processing Record 155 of Set 4 | longyearbyen
# Processing Record 156 of Set 4 | waipawa
# Processing Record 157 of Set 4 | kununurra
# Processing Record 158 of Set 4 | fandriana
# Processing Record 159 of Set 4 | butaritari
# Processing Record 160 of Set 4 | lemesos
# City not found. Skipping ...
# Processing Record 161 of Set 4 | tocopilla
# Processing Record 162 of Set 4 | barrow
# Processing Record 163 of Set 4 | yerofey pavlovich
# Processing Record 164 of Set 4 | lolua
# City not found. Skipping ...
# Processing Record 165 of Set 4 | gornozavodsk
# Processing Record 166 of Set 4 | aloleng
# Processing Record 167 of Set 4 | tsihombe
# City not found. Skipping ...
# Processing Record 168 of Set 4 | uaua
# Processing Record 169 of Set 4 | sorvag
# City not found. Skipping ...
# Processing Record 170 of Set 4 | egvekinot
# Processing Record 171 of Set 4 | storslett
# Processing Record 172 of Set 4 | georgetown
# Processing Record 173 of Set 4 | yantal
# Processing Record 174 of Set 4 | itirucu
# Processing Record 175 of Set 4 | barentsburg
# City not found. Skipping ...
# Processing Record 176 of Set 4 | grand gaube
# Processing Record 177 of Set 4 | east london
# Processing Record 178 of Set 4 | kalivia thorikou
# City not found. Skipping ...
# Processing Record 179 of Set 4 | lima
# Processing Record 180 of Set 4 | stoyba
# City not found. Skipping ...
# Processing Record 181 of Set 4 | namibe
# Processing Record 182 of Set 4 | birao
# Processing Record 183 of Set 4 | harindanga
# Processing Record 184 of Set 4 | alice springs
# Processing Record 185 of Set 4 | gambela
# Processing Record 186 of Set 4 | leningradskiy
# Processing Record 187 of Set 4 | atuona
# Processing Record 188 of Set 4 | houlton
# Processing Record 189 of Set 4 | rusape
# Processing Record 190 of Set 4 | necochea
# Processing Record 191 of Set 4 | pativilca
# Processing Record 192 of Set 4 | shumerlya
# Processing Record 193 of Set 4 | rexburg
# Processing Record 194 of Set 4 | bluff
# Processing Record 195 of Set 4 | touros
# Processing Record 196 of Set 4 | port-gentil
# Processing Record 197 of Set 4 | kavieng
# Processing Record 198 of Set 4 | nikolskoye
# Processing Record 199 of Set 4 | bubaque
# Processing Record 200 of Set 4 | san angelo
# Processing Record 201 of Set 5 | pulandian
# Processing Record 202 of Set 5 | port alfred
# Processing Record 203 of Set 5 | loiza
# Processing Record 204 of Set 5 | wajir
# Processing Record 205 of Set 5 | carnarvon
# Processing Record 206 of Set 5 | sao filipe
# Processing Record 207 of Set 5 | gazni
# City not found. Skipping ...
# Processing Record 208 of Set 5 | mnogovershinnyy
# Processing Record 209 of Set 5 | malwan
# City not found. Skipping ...
# Processing Record 210 of Set 5 | ketchikan
# Processing Record 211 of Set 5 | mezen
# Processing Record 212 of Set 5 | torbay
# Processing Record 213 of Set 5 | chifeng
# Processing Record 214 of Set 5 | la rioja
# Processing Record 215 of Set 5 | alugan
# Processing Record 216 of Set 5 | kodiak
# Processing Record 217 of Set 5 | mecca
# Processing Record 218 of Set 5 | tabas
# Processing Record 219 of Set 5 | souillac
# Processing Record 220 of Set 5 | bengkulu
# Processing Record 221 of Set 5 | olafsvik
# Processing Record 222 of Set 5 | mahajanga
# Processing Record 223 of Set 5 | botiza
# Processing Record 224 of Set 5 | itarema
# Processing Record 225 of Set 5 | kyren
# Processing Record 226 of Set 5 | ambilobe
# Processing Record 227 of Set 5 | bethel
# Processing Record 228 of Set 5 | elko
# Processing Record 229 of Set 5 | williston
# Processing Record 230 of Set 5 | rio grande
# Processing Record 231 of Set 5 | san cristobal
# Processing Record 232 of Set 5 | tuktoyaktuk
# Processing Record 233 of Set 5 | bathsheba
# Processing Record 234 of Set 5 | sambava
# Processing Record 235 of Set 5 | menongue
# Processing Record 236 of Set 5 | rocha
# Processing Record 237 of Set 5 | bambous virieux
# Processing Record 238 of Set 5 | geelong
# Processing Record 239 of Set 5 | abalak
# Processing Record 240 of Set 5 | saint-augustin
# Processing Record 241 of Set 5 | nuuk
# Processing Record 242 of Set 5 | san patricio
# Processing Record 243 of Set 5 | upernavik
# Processing Record 244 of Set 5 | sitka
# Processing Record 245 of Set 5 | ondorhaan
# City not found. Skipping ...
# Processing Record 246 of Set 5 | asmara
# Processing Record 247 of Set 5 | umm lajj
# Processing Record 248 of Set 5 | shenjiamen
# Processing Record 249 of Set 5 | college
# Processing Record 250 of Set 5 | qaanaaq
# Processing Record 251 of Set 6 | porto novo
# Processing Record 252 of Set 6 | ushtobe
# Processing Record 253 of Set 6 | brigantine
# Processing Record 254 of Set 6 | bud
# Processing Record 255 of Set 6 | vaitupu
# City not found. Skipping ...
# Processing Record 256 of Set 6 | khandyga
# Processing Record 257 of Set 6 | bandarbeyla
# Processing Record 258 of Set 6 | pisco
# Processing Record 259 of Set 6 | champerico
# Processing Record 260 of Set 6 | samarai
# Processing Record 261 of Set 6 | constitucion
# Processing Record 262 of Set 6 | nakusp
# Processing Record 263 of Set 6 | luzilandia
# Processing Record 264 of Set 6 | tikapur
# Processing Record 265 of Set 6 | morondava
# Processing Record 266 of Set 6 | bridgewater
# Processing Record 267 of Set 6 | kahului
# Processing Record 268 of Set 6 | sao joao da barra
# Processing Record 269 of Set 6 | mahebourg
# Processing Record 270 of Set 6 | lavrentiya
# Processing Record 271 of Set 6 | maragogi
# Processing Record 272 of Set 6 | kemijarvi
# Processing Record 273 of Set 6 | carlisle
# Processing Record 274 of Set 6 | berlevag
# Processing Record 275 of Set 6 | esperance
# Processing Record 276 of Set 6 | jiaonan
# Processing Record 277 of Set 6 | shimoda
# Processing Record 278 of Set 6 | bereda
# Processing Record 279 of Set 6 | port hedland
# Processing Record 280 of Set 6 | dharchula
# Processing Record 281 of Set 6 | mouzakion
# City not found. Skipping ...
# Processing Record 282 of Set 6 | goderich
# Processing Record 283 of Set 6 | zelenoborsk
# Processing Record 284 of Set 6 | pontivy
# Processing Record 285 of Set 6 | sunbury
# Processing Record 286 of Set 6 | saint george
# Processing Record 287 of Set 6 | otavi
# Processing Record 288 of Set 6 | weligama
# Processing Record 289 of Set 6 | whitehorse
# Processing Record 290 of Set 6 | ituni
# City not found. Skipping ...
# Processing Record 291 of Set 6 | attawapiskat
# City not found. Skipping ...
# Processing Record 292 of Set 6 | bellinzona
# Processing Record 293 of Set 6 | klaksvik
# Processing Record 294 of Set 6 | pemangkat
# Processing Record 295 of Set 6 | nanortalik
# Processing Record 296 of Set 6 | avera
# Processing Record 297 of Set 6 | bouna
# Processing Record 298 of Set 6 | amderma
# City not found. Skipping ...
# Processing Record 299 of Set 6 | padang
# Processing Record 300 of Set 6 | luce
# Processing Record 301 of Set 7 | jieshi
# Processing Record 302 of Set 7 | broken hill
# Processing Record 303 of Set 7 | halalo
# City not found. Skipping ...
# Processing Record 304 of Set 7 | utraula
# Processing Record 305 of Set 7 | coldwater
# Processing Record 306 of Set 7 | qasigiannguit
# Processing Record 307 of Set 7 | buraydah
# Processing Record 308 of Set 7 | chizhou
# Processing Record 309 of Set 7 | margate
# Processing Record 310 of Set 7 | naze
# Processing Record 311 of Set 7 | channel-port aux basques
# Processing Record 312 of Set 7 | optasi
# Processing Record 313 of Set 7 | natchitoches
# Processing Record 314 of Set 7 | port lincoln
# Processing Record 315 of Set 7 | simbahan
# Processing Record 316 of Set 7 | saint-joseph
# Processing Record 317 of Set 7 | saint anthony
# Processing Record 318 of Set 7 | half moon bay
# Processing Record 319 of Set 7 | le mans
# Processing Record 320 of Set 7 | malanje
# Processing Record 321 of Set 7 | abiy adi
# City not found. Skipping ...
# Processing Record 322 of Set 7 | okha
# Processing Record 323 of Set 7 | sorland
# Processing Record 324 of Set 7 | samusu
# City not found. Skipping ...
# Processing Record 325 of Set 7 | lafiagi
# Processing Record 326 of Set 7 | alofi
# Processing Record 327 of Set 7 | talnakh
# Processing Record 328 of Set 7 | leh
# Processing Record 329 of Set 7 | bargal
# City not found. Skipping ...
# Processing Record 330 of Set 7 | pankovka
# Processing Record 331 of Set 7 | monroe
# Processing Record 332 of Set 7 | weida
# Processing Record 333 of Set 7 | jiuquan
# Processing Record 334 of Set 7 | lufilufi
# Processing Record 335 of Set 7 | rolim de moura
# City not found. Skipping ...
# Processing Record 336 of Set 7 | teya
# Processing Record 337 of Set 7 | granadilla de abona
# Processing Record 338 of Set 7 | votkinsk
# Processing Record 339 of Set 7 | kotra
# Processing Record 340 of Set 7 | ruatoria
# City not found. Skipping ...
# Processing Record 341 of Set 7 | cabo san lucas
# Processing Record 342 of Set 7 | north bend
# Processing Record 343 of Set 7 | hofn
# Processing Record 344 of Set 7 | buon me thuot
# City not found. Skipping ...
# Processing Record 345 of Set 7 | santa cruz
# Processing Record 346 of Set 7 | lurgan
# Processing Record 347 of Set 7 | ixtapa
# Processing Record 348 of Set 7 | kinarut
# Processing Record 349 of Set 7 | port augusta
# Processing Record 350 of Set 7 | iki-burul
# Processing Record 351 of Set 8 | general roca
# Processing Record 352 of Set 8 | lubango
# Processing Record 353 of Set 8 | san policarpo
# Processing Record 354 of Set 8 | verkhniy avzyan
# Processing Record 355 of Set 8 | portland
# Processing Record 356 of Set 8 | brae
# Processing Record 357 of Set 8 | lensk
# Processing Record 358 of Set 8 | pangody
# Processing Record 359 of Set 8 | wenling
# Processing Record 360 of Set 8 | cherskiy
# Processing Record 361 of Set 8 | san benito
# Processing Record 362 of Set 8 | aalst
# Processing Record 363 of Set 8 | havoysund
# Processing Record 364 of Set 8 | asheville
# Processing Record 365 of Set 8 | longyan
# Processing Record 366 of Set 8 | port blair
# Processing Record 367 of Set 8 | elat
# Processing Record 368 of Set 8 | pampa
# Processing Record 369 of Set 8 | lata
# Processing Record 370 of Set 8 | bagepalli
# Processing Record 371 of Set 8 | shiyan
# Processing Record 372 of Set 8 | halifax
# Processing Record 373 of Set 8 | vulcan
# Processing Record 374 of Set 8 | flinders
# Processing Record 375 of Set 8 | baker city
# Processing Record 376 of Set 8 | ostrovnoy
# Processing Record 377 of Set 8 | kailua
# Processing Record 378 of Set 8 | quixada
# Processing Record 379 of Set 8 | akdagmadeni
# Processing Record 380 of Set 8 | sola
# Processing Record 381 of Set 8 | malpe
# Processing Record 382 of Set 8 | cidreira
# Processing Record 383 of Set 8 | seminole
# Processing Record 384 of Set 8 | paamiut
# Processing Record 385 of Set 8 | of
# City not found. Skipping ...
# Processing Record 386 of Set 8 | daru
# Processing Record 387 of Set 8 | clarksburg
# Processing Record 388 of Set 8 | viedma
# Processing Record 389 of Set 8 | kungurtug
# Processing Record 390 of Set 8 | edson
# Processing Record 391 of Set 8 | nobres
# Processing Record 392 of Set 8 | kez
# Processing Record 393 of Set 8 | dudinka
# Processing Record 394 of Set 8 | esso
# Processing Record 395 of Set 8 | xuddur
# Processing Record 396 of Set 8 | fortuna
# Processing Record 397 of Set 8 | novoagansk
# Processing Record 398 of Set 8 | jishou
# Processing Record 399 of Set 8 | kamaishi
# Processing Record 400 of Set 8 | pauini
# Processing Record 401 of Set 9 | kathmandu
# Processing Record 402 of Set 9 | kindu
# Processing Record 403 of Set 9 | anadyr
# Processing Record 404 of Set 9 | severnoye
# Processing Record 405 of Set 9 | vestmannaeyjar
# Processing Record 406 of Set 9 | nagato
# Processing Record 407 of Set 9 | carutapera
# Processing Record 408 of Set 9 | goundam
# Processing Record 409 of Set 9 | faya
# Processing Record 410 of Set 9 | coracora
# Processing Record 411 of Set 9 | grand river south east
# City not found. Skipping ...
# Processing Record 412 of Set 9 | muroto
# Processing Record 413 of Set 9 | canutama
# Processing Record 414 of Set 9 | maputo
# Processing Record 415 of Set 9 | rio gallegos
# Processing Record 416 of Set 9 | jalu
# Processing Record 417 of Set 9 | okhotsk
# Processing Record 418 of Set 9 | araouane
# Processing Record 419 of Set 9 | kencong
# Processing Record 420 of Set 9 | high level
# Processing Record 421 of Set 9 | jiroft
# City not found. Skipping ...
# Processing Record 422 of Set 9 | byron bay
# Processing Record 423 of Set 9 | ailigandi
# Processing Record 424 of Set 9 | hami
# Processing Record 425 of Set 9 | delmenhorst
# Processing Record 426 of Set 9 | haines junction
# Processing Record 427 of Set 9 | eidsvag
# Processing Record 428 of Set 9 | kulhudhuffushi
# Processing Record 429 of Set 9 | tura
# Processing Record 430 of Set 9 | codrington
# Processing Record 431 of Set 9 | jabiru
# City not found. Skipping ...
# Processing Record 432 of Set 9 | doka
# Processing Record 433 of Set 9 | acajutla
# Processing Record 434 of Set 9 | manacapuru
# Processing Record 435 of Set 9 | nguiu
# City not found. Skipping ...
# Processing Record 436 of Set 9 | arenal
# Processing Record 437 of Set 9 | tiruvottiyur
# City not found. Skipping ...
# Processing Record 438 of Set 9 | paripiranga
# Processing Record 439 of Set 9 | chapais
# Processing Record 440 of Set 9 | mamallapuram
# Processing Record 441 of Set 9 | walvis bay
# Processing Record 442 of Set 9 | domodossola
# Processing Record 443 of Set 9 | mancio lima
# Processing Record 444 of Set 9 | williamsport
# Processing Record 445 of Set 9 | xining
# Processing Record 446 of Set 9 | terrace
# Processing Record 447 of Set 9 | jaru
# Processing Record 448 of Set 9 | corinto
# Processing Record 449 of Set 9 | basco
# Processing Record 450 of Set 9 | tabiauea
# City not found. Skipping ...
# Processing Record 451 of Set 10 | caditaan
# Processing Record 452 of Set 10 | tvoroyri
# Processing Record 453 of Set 10 | dzhusaly
# City not found. Skipping ...
# Processing Record 454 of Set 10 | port shepstone
# Processing Record 455 of Set 10 | manama
# Processing Record 456 of Set 10 | husavik
# Processing Record 457 of Set 10 | westport
# Processing Record 458 of Set 10 | harlingen
# Processing Record 459 of Set 10 | the valley
# Processing Record 460 of Set 10 | chirongui
# Processing Record 461 of Set 10 | clyde river
# Processing Record 462 of Set 10 | imeni poliny osipenko
# Processing Record 463 of Set 10 | muncar
# Processing Record 464 of Set 10 | pacifica
# Processing Record 465 of Set 10 | poum
# Processing Record 466 of Set 10 | luganville
# Processing Record 467 of Set 10 | hanzhong
# Processing Record 468 of Set 10 | adre
# Processing Record 469 of Set 10 | yuanping
# Processing Record 470 of Set 10 | kamenka
# Processing Record 471 of Set 10 | nizhniy kuranakh
# Processing Record 472 of Set 10 | dunedin
# Processing Record 473 of Set 10 | boueni
# Processing Record 474 of Set 10 | panjwin
# City not found. Skipping ...
# Processing Record 475 of Set 10 | marsh harbour
# Processing Record 476 of Set 10 | ullapool
# Processing Record 477 of Set 10 | derzhavinsk
# Processing Record 478 of Set 10 | katsiveli
# City not found. Skipping ...
# Processing Record 479 of Set 10 | hernani
# Processing Record 480 of Set 10 | zabol
# Processing Record 481 of Set 10 | pandan
# Processing Record 482 of Set 10 | maxixe
# Processing Record 483 of Set 10 | chimbote
# Processing Record 484 of Set 10 | yumen
# Processing Record 485 of Set 10 | wulanhaote
# City not found. Skipping ...
# Processing Record 486 of Set 10 | chiang klang
# Processing Record 487 of Set 10 | nha trang
# Processing Record 488 of Set 10 | vao
# Processing Record 489 of Set 10 | vila velha
# Processing Record 490 of Set 10 | caluquembe
# Processing Record 491 of Set 10 | cayenne
# Processing Record 492 of Set 10 | laizhou
# Processing Record 493 of Set 10 | maua
# Processing Record 494 of Set 10 | conceicao do araguaia
# Processing Record 495 of Set 10 | borba
# Processing Record 496 of Set 10 | maceio
# Processing Record 497 of Set 10 | hasaki
# Processing Record 498 of Set 10 | yurino
# Processing Record 499 of Set 10 | playas
# Processing Record 500 of Set 10 | ust-ishim
# Processing Record 501 of Set 11 | smithers
# Processing Record 502 of Set 11 | hambantota
# Processing Record 503 of Set 11 | arlit
# Processing Record 504 of Set 11 | eureka
# Processing Record 505 of Set 11 | pitiquito
# Processing Record 506 of Set 11 | saleaula
# City not found. Skipping ...
# Processing Record 507 of Set 11 | artyk
# City not found. Skipping ...
# Processing Record 508 of Set 11 | wonosobo
# Processing Record 509 of Set 11 | mahon
# Processing Record 510 of Set 11 | rosario
# Processing Record 511 of Set 11 | quatre cocos
# Processing Record 512 of Set 11 | kedrovyy
# Processing Record 513 of Set 11 | simao
# Processing Record 514 of Set 11 | porto velho
# Processing Record 515 of Set 11 | maldonado
# Processing Record 516 of Set 11 | mayo
# Processing Record 517 of Set 11 | mount isa
# Processing Record 518 of Set 11 | awjilah
# Processing Record 519 of Set 11 | puerto el triunfo
# Processing Record 520 of Set 11 | babanusah
# City not found. Skipping ...
# Processing Record 521 of Set 11 | suntar
# Processing Record 522 of Set 11 | labutta
# City not found. Skipping ...
# Processing Record 523 of Set 11 | chase
# Processing Record 524 of Set 11 | kuala pilah
# Processing Record 525 of Set 11 | callaway
# Processing Record 526 of Set 11 | dire
# Processing Record 527 of Set 11 | korba
# Processing Record 528 of Set 11 | gorontalo
# Processing Record 529 of Set 11 | bayangol
# Processing Record 530 of Set 11 | palabuhanratu
# City not found. Skipping ...
# Processing Record 531 of Set 11 | jiblah
# Processing Record 532 of Set 11 | cheuskiny
# City not found. Skipping ...
# Processing Record 533 of Set 11 | haimen
# Processing Record 534 of Set 11 | bogoroditsk
# Processing Record 535 of Set 11 | mariental
# Processing Record 536 of Set 11 | fethiye
# Processing Record 537 of Set 11 | mpwapwa
# Processing Record 538 of Set 11 | kaputa
# Processing Record 539 of Set 11 | paradwip
# City not found. Skipping ...
# Processing Record 540 of Set 11 | roebourne
# Processing Record 541 of Set 11 | svetlogorsk
# Processing Record 542 of Set 11 | ossora
# Processing Record 543 of Set 11 | belaya gora
# Processing Record 544 of Set 11 | pavlodar
# Processing Record 545 of Set 11 | broome
# Processing Record 546 of Set 11 | tezpur
# Processing Record 547 of Set 11 | mikhaylov
# Processing Record 548 of Set 11 | manicore
# Processing Record 549 of Set 11 | kaeo
# Processing Record 550 of Set 11 | hervey bay
# Processing Record 551 of Set 12 | fuchu
# Processing Record 552 of Set 12 | pombas
# Processing Record 553 of Set 12 | callaguip
# Processing Record 554 of Set 12 | murchison
# Processing Record 555 of Set 12 | mingshui
# Processing Record 556 of Set 12 | manggar
# Processing Record 557 of Set 12 | urumqi
# Processing Record 558 of Set 12 | sosnogorsk
# Processing Record 559 of Set 12 | pinheiro machado
# Processing Record 560 of Set 12 | labuhan
# Processing Record 561 of Set 12 | omsukchan
# Processing Record 562 of Set 12 | lashio
# Processing Record 563 of Set 12 | coquimbo
# Processing Record 564 of Set 12 | folldal
# Processing Record 565 of Set 12 | mugur-aksy
# Processing Record 566 of Set 12 | mogadishu
# Processing Record 567 of Set 12 | san francisco del mar
# Processing Record 568 of Set 12 | bukachacha
# Processing Record 569 of Set 12 | mount gambier
# Processing Record 570 of Set 12 | waingapu
# Processing Record 571 of Set 12 | skagastrond
# City not found. Skipping ...
# Processing Record 572 of Set 12 | mount pleasant
# Processing Record 573 of Set 12 | miraflores
# Processing Record 574 of Set 12 | yuancheng
# Processing Record 575 of Set 12 | aykhal
# Processing Record 576 of Set 12 | beisfjord
# Processing Record 577 of Set 12 | kihei
# Processing Record 578 of Set 12 | pimentel
# Processing Record 579 of Set 12 | sandakan
# Processing Record 580 of Set 12 | yenisehir
# Processing Record 581 of Set 12 | quballat
# Processing Record 582 of Set 12 | fare
# Processing Record 583 of Set 12 | satitoa
# City not found. Skipping ...
# Processing Record 584 of Set 12 | kangly
# Processing Record 585 of Set 12 | lasa
# Processing Record 586 of Set 12 | presidencia roque saenz pena
# Processing Record 587 of Set 12 | waddan
# Processing Record 588 of Set 12 | hoquiam
# Processing Record 589 of Set 12 | vallenar
# Processing Record 590 of Set 12 | aswan
# Processing Record 591 of Set 12 | richmond
# Processing Record 592 of Set 12 | harper
# Processing Record 593 of Set 12 | juneau
# Processing Record 594 of Set 12 | weilmunster
# Processing Record 595 of Set 12 | puerto maldonado
# Processing Record 596 of Set 12 | poli
# Processing Record 597 of Set 12 | salinas
# Processing Record 598 of Set 12 | karamay
# City not found. Skipping ...
# Processing Record 599 of Set 12 | bowen
# Processing Record 600 of Set 12 | santa maria
# Processing Record 601 of Set 13 | beyneu
# Processing Record 602 of Set 13 | zhob
# Processing Record 603 of Set 13 | srednekolymsk
# Processing Record 604 of Set 13 | tuatapere
# Processing Record 605 of Set 13 | bosaso
# Processing Record 606 of Set 13 | altus
# Processing Record 607 of Set 13 | dawlatabad
# Processing Record 608 of Set 13 | yulin
# Processing Record 609 of Set 13 | mullaitivu
# City not found. Skipping ...
# Processing Record 610 of Set 13 | douglas
# Processing Record 611 of Set 13 | panzhihua
# Processing Record 612 of Set 13 | vila franca do campo
# Processing Record 613 of Set 13 | damoh
# Processing Record 614 of Set 13 | pak phanang
# Processing Record 615 of Set 13 | qaqortoq
# Processing Record 616 of Set 13 | ginda
# Processing Record 617 of Set 13 | mana
# Processing Record 618 of Set 13 | rebrikha
# Processing Record 619 of Set 13 | karratha
# Processing Record 620 of Set 13 | valparaiso
# Processing Record 621 of Set 13 | los llanos de aridane
# Processing Record 622 of Set 13 | aksarka
# Processing Record 623 of Set 13 | kilindoni
# Processing Record 624 of Set 13 | erdenet
# Processing Record 625 of Set 13 | san roque
# Processing Record 626 of Set 13 | khani
# Processing Record 627 of Set 13 | litoral del san juan
# City not found. Skipping ...
# Processing Record 628 of Set 13 | ust-uda
# Processing Record 629 of Set 13 | abu samrah
# Processing Record 630 of Set 13 | paramonga
# Processing Record 631 of Set 13 | laguna
# Processing Record 632 of Set 13 | yanam
# Processing Record 633 of Set 13 | sattahip
# Processing Record 634 of Set 13 | lanxi
# Processing Record 635 of Set 13 | gavle
# Processing Record 636 of Set 13 | ahuimanu
# Processing Record 637 of Set 13 | gazimurskiy zavod
# Processing Record 638 of Set 13 | saint-maximin-la-sainte-baume
# Processing Record 639 of Set 13 | alenquer
# Processing Record 640 of Set 13 | sergeyevka
# Processing Record 641 of Set 13 | bintulu
# Processing Record 642 of Set 13 | tirumullaivasal
# Processing Record 643 of Set 13 | koumac
# Processing Record 644 of Set 13 | bilma
# Processing Record 645 of Set 13 | aljezur
# Processing Record 646 of Set 13 | sinnamary
# Processing Record 647 of Set 13 | yuzhou
# Processing Record 648 of Set 13 | moose factory
# Processing Record 649 of Set 13 | linguere
# Processing Record 650 of Set 13 | matagami
# Processing Record 651 of Set 14 | saryshagan
# City not found. Skipping ...
# Processing Record 652 of Set 14 | caravelas
# Processing Record 653 of Set 14 | mandera
# Processing Record 654 of Set 14 | tateyama
# Processing Record 655 of Set 14 | price
# Processing Record 656 of Set 14 | williams lake
# Processing Record 657 of Set 14 | tancheng
# Processing Record 658 of Set 14 | bambanglipuro
# Processing Record 659 of Set 14 | quelimane
# Processing Record 660 of Set 14 | sistranda
# Processing Record 661 of Set 14 | iranshahr
# Processing Record 662 of Set 14 | kavaratti
# Processing Record 663 of Set 14 | tsienyane
# City not found. Skipping ...
# Processing Record 664 of Set 14 | ucluelet
# Processing Record 665 of Set 14 | karaul
# City not found. Skipping ...
# Processing Record 666 of Set 14 | witrivier
# City not found. Skipping ...
# Processing Record 667 of Set 14 | riyadh
# Processing Record 668 of Set 14 | cuiluan
# Processing Record 669 of Set 14 | kimbe
# Processing Record 670 of Set 14 | lompoc
# Processing Record 671 of Set 14 | inhambane
# Processing Record 672 of Set 14 | libenge
# Processing Record 673 of Set 14 | surt
# Processing Record 674 of Set 14 | katangli
# Processing Record 675 of Set 14 | mazagao
# Processing Record 676 of Set 14 | wasilla
# Processing Record 677 of Set 14 | raudeberg
# Processing Record 678 of Set 14 | chabahar
# Processing Record 679 of Set 14 | maningrida
# Processing Record 680 of Set 14 | kinshasa
# Processing Record 681 of Set 14 | kaoma
# Processing Record 682 of Set 14 | batagay
# Processing Record 683 of Set 14 | kargasok
# Processing Record 684 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 685 of Set 14 | razole
# Processing Record 686 of Set 14 | takoradi
# Processing Record 687 of Set 14 | martaban
# Processing Record 688 of Set 14 | bad driburg
# Processing Record 689 of Set 14 | krasnoarmeysk
# Processing Record 690 of Set 14 | zharkent
# Processing Record 691 of Set 14 | vanderhoof
# Processing Record 692 of Set 14 | viligili
# City not found. Skipping ...
# Processing Record 693 of Set 14 | minab
# Processing Record 694 of Set 14 | manado
# Processing Record 695 of Set 14 | puri
# Processing Record 696 of Set 14 | rawson
# Processing Record 697 of Set 14 | maarianhamina
# Processing Record 698 of Set 14 | onega
# Processing Record 699 of Set 14 | kedgwick
# Processing Record 700 of Set 14 | libreville
# Processing Record 701 of Set 15 | sao raimundo nonato
# Processing Record 702 of Set 15 | santiago del estero
# Processing Record 703 of Set 15 | abu dhabi
# Processing Record 704 of Set 15 | gunjur
# Processing Record 705 of Set 15 | celle
# Processing Record 706 of Set 15 | nelson bay
# Processing Record 707 of Set 15 | matara
# Processing Record 708 of Set 15 | vestmanna
# Processing Record 709 of Set 15 | muisne
# Processing Record 710 of Set 15 | jalapa
# Processing Record 711 of Set 15 | cabadiangan
# Processing Record 712 of Set 15 | durban
# Processing Record 713 of Set 15 | yarada
# Processing Record 714 of Set 15 | oranjestad
# Processing Record 715 of Set 15 | sechura
# Processing Record 716 of Set 15 | havre-saint-pierre
# Processing Record 717 of Set 15 | bradley
# Processing Record 718 of Set 15 | aksum
# Processing Record 719 of Set 15 | baft
# Processing Record 720 of Set 15 | greeneville
# Processing Record 721 of Set 15 | pasighat
# Processing Record 722 of Set 15 | shelburne
# Processing Record 723 of Set 15 | manta
# Processing Record 724 of Set 15 | zhigansk
# Processing Record 725 of Set 15 | oriximina
# Processing Record 726 of Set 15 | vostok
# Processing Record 727 of Set 15 | katangi
# Processing Record 728 of Set 15 | leninskoye
# Processing Record 729 of Set 15 | shache
# Processing Record 730 of Set 15 | gao
# Processing Record 731 of Set 15 | paris
# Processing Record 732 of Set 15 | inirida
# Processing Record 733 of Set 15 | mys shmidta
# City not found. Skipping ...
# Processing Record 734 of Set 15 | kelvington
# Processing Record 735 of Set 15 | carballo
# Processing Record 736 of Set 15 | zachagansk
# City not found. Skipping ...
# Processing Record 737 of Set 15 | tilichiki
# Processing Record 738 of Set 15 | teo
# Processing Record 739 of Set 15 | jiaozuo
# Processing Record 740 of Set 15 | imeni babushkina
# Processing Record 741 of Set 15 | coracao de jesus
# Processing Record 742 of Set 15 | kjollefjord
# Processing Record 743 of Set 15 | cavalcante
# Processing Record 744 of Set 15 | amapa
# Processing Record 745 of Set 15 | sibu
# Processing Record 746 of Set 15 | rey bouba
# Processing Record 747 of Set 15 | mirabad
# Processing Record 748 of Set 15 | tornio
# Processing Record 749 of Set 15 | rio de janeiro
# Processing Record 750 of Set 15 | ordynskoye
# Processing Record 751 of Set 16 | cabatuan
# Processing Record 752 of Set 16 | loikaw
# Processing Record 753 of Set 16 | danville
# Processing Record 754 of Set 16 | chhata
# Processing Record 755 of Set 16 | vicuna
# Processing Record 756 of Set 16 | ushibuka
# Processing Record 757 of Set 16 | lincoln
# Processing Record 758 of Set 16 | mehamn
# Processing Record 759 of Set 16 | fairbanks
# Processing Record 760 of Set 16 | port hardy
# Processing Record 761 of Set 16 | middelburg
# Processing Record 762 of Set 16 | doha
# Processing Record 763 of Set 16 | evensk
# Processing Record 764 of Set 16 | hailun
# Processing Record 765 of Set 16 | touho
# Processing Record 766 of Set 16 | mrirt
# City not found. Skipping ...
# Processing Record 767 of Set 16 | inderborskiy
# City not found. Skipping ...
# Processing Record 768 of Set 16 | deputatskiy
# Processing Record 769 of Set 16 | pyay
# Processing Record 770 of Set 16 | granger
# Processing Record 771 of Set 16 | asyut
# Processing Record 772 of Set 16 | erzincan
# Processing Record 773 of Set 16 | cockburn town
# Processing Record 774 of Set 16 | beloha
# Processing Record 775 of Set 16 | mahibadhoo
# Processing Record 776 of Set 16 | jega
# Processing Record 777 of Set 16 | ellon
# Processing Record 778 of Set 16 | akyab
# Processing Record 779 of Set 16 | hammerfest
# Processing Record 780 of Set 16 | chicama
# Processing Record 781 of Set 16 | punto fijo
# Processing Record 782 of Set 16 | gigmoto
# Processing Record 783 of Set 16 | seddon
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 714

# %%
#Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Thompson  55.7435  -97.8558     62.76        77           0        9.22
# 1        Vardo  70.3705   31.1107     48.18        81         100       21.85
# 2        Vaini -21.2000 -175.2000     66.36        94          20        4.61
# 3      Rikitea -23.1203 -134.9692     70.84        64         100       17.38
# 4       Avarua -21.2078 -159.7750     71.65        83          99        3.44
# 5  Provideniya  64.3833 -173.3000     43.79        90          98       10.67
# 6   Chokurdakh  70.6333  147.9167     35.96        97         100       14.07
# 7       Dikson  73.5069   80.5464     41.00        79          30       15.32
# 8     Bagdarin  54.4333  113.6000     39.42        98         100        7.34
# 9        Kabwe -14.4469   28.4464     84.20        19           0        8.75
#
#   Country Current Description
# 0      CA           clear sky
# 1      NO     overcast clouds
# 2      TO          few clouds
# 3      PF     overcast clouds
# 4      CK     overcast clouds
# 5      RU     overcast clouds
# 6      RU          light rain
# 7      RU    scattered clouds
# 8      RU     overcast clouds
# 9      ZM           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
#Create the output file (CSV).

output_data_file = "WeatherPy_Database.csv"

#Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label = "City_ID")
